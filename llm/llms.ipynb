# %% [markdown]
# ## Global Dependencies

# %%
import sys
import os
# !{sys.executable} -m pip install torch
# !{sys.executable} -m pip install defeatbeta-api
# !{sys.executable} -m pip install diffusers
# !{sys.executable} -m pip install huggingface-hub
# !{sys.executable} -m pip install ipywidgets
# !{sys.executable} -m pip install sentence-transformers
# Out:
# Requirement already satisfied: torch in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (2.10.0)
# Requirement already satisfied: filelock in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from torch) (2025.10.0)
# Requirement already satisfied: setuptools in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: defeatbeta-api in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (0.0.31)
# Requirement already satisfied: duckdb>=1.4.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (1.4.4)
# Requirement already satisfied: pandas>=2.2.3 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (2.3.3)
# Requirement already satisfied: requests~=2.32.3 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (2.32.5)
# Requirement already satisfied: psutil>=7.0.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (7.1.0)
# Requirement already satisfied: pyfiglet>=1.0.2 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (1.0.4)
# Requirement already satisfied: urllib3>=2.6.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (2.6.3)
# Requirement already satisfied: tabulate>=0.9.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (0.9.0)
# Requirement already satisfied: numpy>=2.2.5 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (2.3.3)
# Requirement already satisfied: rich>=14.0.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (14.3.1)
# Requirement already satisfied: openai>=1.106.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (2.15.0)
# Requirement already satisfied: nltk>=3.9.2 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (3.9.2)
# Requirement already satisfied: datasets>=4.4.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (4.5.0)
# Requirement already satisfied: huggingface_hub>=1.1.2 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (1.3.4)
# Requirement already satisfied: pyarrow>=22.0.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (23.0.0)
# Requirement already satisfied: ipython<=8.37.0,>=8.0.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (8.37.0)
# Requirement already satisfied: matplotlib>=3.10.7 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (3.10.8)
# Requirement already satisfied: seaborn>=0.13.2 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (0.13.2)
# Requirement already satisfied: mcp>=1.25.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from defeatbeta-api) (1.26.0)
# Requirement already satisfied: colorama in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipython<=8.37.0,>=8.0.0->defeatbeta-api) (0.4.6)
# Requirement already satisfied: decorator in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipython<=8.37.0,>=8.0.0->defeatbeta-api) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipython<=8.37.0,>=8.0.0->defeatbeta-api) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipython<=8.37.0,>=8.0.0->defeatbeta-api) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipython<=8.37.0,>=8.0.0->defeatbeta-api) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipython<=8.37.0,>=8.0.0->defeatbeta-api) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipython<=8.37.0,>=8.0.0->defeatbeta-api) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipython<=8.37.0,>=8.0.0->defeatbeta-api) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<=8.37.0,>=8.0.0->defeatbeta-api) (0.2.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from requests~=2.32.3->defeatbeta-api) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from requests~=2.32.3->defeatbeta-api) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from requests~=2.32.3->defeatbeta-api) (2025.8.3)
# Requirement already satisfied: filelock in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from datasets>=4.4.1->defeatbeta-api) (3.20.3)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from datasets>=4.4.1->defeatbeta-api) (0.4.0)
# Requirement already satisfied: httpx<1.0.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from datasets>=4.4.1->defeatbeta-api) (0.28.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from datasets>=4.4.1->defeatbeta-api) (4.67.1)
# Requirement already satisfied: xxhash in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from datasets>=4.4.1->defeatbeta-api) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.19 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from datasets>=4.4.1->defeatbeta-api) (0.70.18)
# Requirement already satisfied: fsspec<=2025.10.0,>=2023.1.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=4.4.1->defeatbeta-api) (2025.10.0)
# Requirement already satisfied: packaging in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from datasets>=4.4.1->defeatbeta-api) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from datasets>=4.4.1->defeatbeta-api) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=4.4.1->defeatbeta-api) (3.13.3)
# Requirement already satisfied: anyio in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0->datasets>=4.4.1->defeatbeta-api) (4.11.0)
# Requirement already satisfied: httpcore==1.* in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0->datasets>=4.4.1->defeatbeta-api) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets>=4.4.1->defeatbeta-api) (0.16.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub>=1.1.2->defeatbeta-api) (1.2.0)
# Requirement already satisfied: shellingham in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub>=1.1.2->defeatbeta-api) (1.5.4)
# Requirement already satisfied: typer-slim in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub>=1.1.2->defeatbeta-api) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface_hub>=1.1.2->defeatbeta-api) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=4.4.1->defeatbeta-api) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=4.4.1->defeatbeta-api) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=4.4.1->defeatbeta-api) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=4.4.1->defeatbeta-api) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=4.4.1->defeatbeta-api) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=4.4.1->defeatbeta-api) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.10.0,>=2023.1.0->datasets>=4.4.1->defeatbeta-api) (1.22.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from jedi>=0.16->ipython<=8.37.0,>=8.0.0->defeatbeta-api) (0.8.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.10.7->defeatbeta-api) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.10.7->defeatbeta-api) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.10.7->defeatbeta-api) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.10.7->defeatbeta-api) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.10.7->defeatbeta-api) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.10.7->defeatbeta-api) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.10.7->defeatbeta-api) (2.9.0.post0)
# Requirement already satisfied: httpx-sse>=0.4 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.25.0->defeatbeta-api) (0.4.3)
# Requirement already satisfied: jsonschema>=4.20.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.25.0->defeatbeta-api) (4.25.1)
# Requirement already satisfied: pydantic-settings>=2.5.2 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.25.0->defeatbeta-api) (2.12.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.11.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.25.0->defeatbeta-api) (2.12.5)
# Requirement already satisfied: pyjwt>=2.10.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.25.0->defeatbeta-api) (2.10.1)
# Requirement already satisfied: python-multipart>=0.0.9 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.25.0->defeatbeta-api) (0.0.22)
# Requirement already satisfied: pywin32>=310 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.25.0->defeatbeta-api) (311)
# Requirement already satisfied: sse-starlette>=1.6.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.25.0->defeatbeta-api) (3.2.0)
# Requirement already satisfied: starlette>=0.27 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.25.0->defeatbeta-api) (0.52.1)
# Requirement already satisfied: typing-inspection>=0.4.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.25.0->defeatbeta-api) (0.4.2)
# Requirement already satisfied: uvicorn>=0.31.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from mcp>=1.25.0->defeatbeta-api) (0.40.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.11.0->mcp>=1.25.0->defeatbeta-api) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3.0.0,>=2.11.0->mcp>=1.25.0->defeatbeta-api) (2.41.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1.0.0->datasets>=4.4.1->defeatbeta-api) (1.3.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.25.0->defeatbeta-api) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.25.0->defeatbeta-api) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from jsonschema>=4.20.0->mcp>=1.25.0->defeatbeta-api) (0.27.1)
# Requirement already satisfied: click in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9.2->defeatbeta-api) (8.3.1)
# Requirement already satisfied: joblib in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9.2->defeatbeta-api) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from nltk>=3.9.2->defeatbeta-api) (2026.1.15)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from openai>=1.106.1->defeatbeta-api) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from openai>=1.106.1->defeatbeta-api) (0.12.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from pandas>=2.2.3->defeatbeta-api) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from pandas>=2.2.3->defeatbeta-api) (2025.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from pydantic-settings>=2.5.2->mcp>=1.25.0->defeatbeta-api) (1.2.1)
# Requirement already satisfied: cryptography>=3.4.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from pyjwt[crypto]>=2.10.1->mcp>=1.25.0->defeatbeta-api) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=1.25.0->defeatbeta-api) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from cffi>=2.0.0->cryptography>=3.4.0->pyjwt[crypto]>=2.10.1->mcp>=1.25.0->defeatbeta-api) (2.23)
# Requirement already satisfied: six>=1.5 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.7->defeatbeta-api) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from rich>=14.0.0->defeatbeta-api) (4.0.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from markdown-it-py>=2.2.0->rich>=14.0.0->defeatbeta-api) (0.1.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython<=8.37.0,>=8.0.0->defeatbeta-api) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython<=8.37.0,>=8.0.0->defeatbeta-api) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython<=8.37.0,>=8.0.0->defeatbeta-api) (0.2.3)
# Requirement already satisfied: diffusers in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (0.36.0)
# Requirement already satisfied: importlib_metadata in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (8.7.1)
# Requirement already satisfied: filelock in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (3.20.3)
# Requirement already satisfied: httpx<1.0.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (0.28.1)
# Requirement already satisfied: huggingface-hub<2.0,>=0.34.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (1.3.4)
# Requirement already satisfied: numpy in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (2.3.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (2026.1.15)
# Requirement already satisfied: requests in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (2.32.5)
# Requirement already satisfied: safetensors>=0.3.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (0.7.0)
# Requirement already satisfied: Pillow in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from diffusers) (12.1.0)
# Requirement already satisfied: anyio in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0->diffusers) (4.11.0)
# Requirement already satisfied: certifi in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0->diffusers) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0->diffusers) (1.0.9)
# Requirement already satisfied: idna in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpx<1.0.0->diffusers) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1.0.0->diffusers) (0.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (1.2.0)
# Requirement already satisfied: packaging>=20.9 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (6.0.2)
# Requirement already satisfied: shellingham in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (4.67.1)
# Requirement already satisfied: typer-slim in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<2.0,>=0.34.0->diffusers) (4.15.0)
# Requirement already satisfied: colorama in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<2.0,>=0.34.0->diffusers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1.0.0->diffusers) (1.3.1)
# Requirement already satisfied: zipp>=3.20 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from importlib_metadata->diffusers) (3.23.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from requests->diffusers) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from requests->diffusers) (2.6.3)
# Requirement already satisfied: click>=8.0.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from typer-slim->huggingface-hub<2.0,>=0.34.0->diffusers) (8.3.1)
# Requirement already satisfied: huggingface-hub in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (1.3.4)
# Requirement already satisfied: filelock in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub) (3.20.3)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub) (6.0.2)
# Requirement already satisfied: shellingham in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub) (4.67.1)
# Requirement already satisfied: typer-slim in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub) (4.15.0)
# Requirement already satisfied: anyio in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub) (4.11.0)
# Requirement already satisfied: certifi in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub) (1.0.9)
# Requirement already satisfied: idna in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub) (0.16.0)
# Requirement already satisfied: colorama in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from tqdm>=4.42.1->huggingface-hub) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub) (1.3.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from typer-slim->huggingface-hub) (8.3.1)
# Requirement already satisfied: ipywidgets in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (8.1.8)
# Requirement already satisfied: comm>=0.1.3 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (8.37.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: colorama in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Collecting sentence-transformers
#   Downloading sentence_transformers-5.2.2-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: transformers<6.0.0,>=4.41.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (5.0.1.dev0)
# Requirement already satisfied: huggingface-hub>=0.20.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (1.3.4)
# Requirement already satisfied: torch>=1.11.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (2.10.0)
# Requirement already satisfied: numpy in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (2.3.3)
# Requirement already satisfied: scikit-learn in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (1.7.2)
# Requirement already satisfied: scipy in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (1.16.2)
# Requirement already satisfied: typing_extensions>=4.5.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: tqdm in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: filelock in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (3.20.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (2026.1.15)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.22.2)
# Requirement already satisfied: typer-slim in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from transformers<6.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (0.28.1)
# Requirement already satisfied: shellingham in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.5.4)
# Requirement already satisfied: anyio in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (4.11.0)
# Requirement already satisfied: certifi in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.0.9)
# Requirement already satisfied: idna in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (0.16.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.6.1)
# Requirement already satisfied: jinja2 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from torch>=1.11.0->sentence-transformers) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: colorama in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from tqdm->sentence-transformers) (0.4.6)
# Requirement already satisfied: sniffio>=1.1 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from anyio->httpx<1,>=0.23.0->huggingface-hub>=0.20.0->sentence-transformers) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: click>=8.0.0 in c:\users\marcu\appdata\local\programs\python\python313\lib\site-packages (from typer-slim->transformers<6.0.0,>=4.41.0->sentence-transformers) (8.3.1)
# Downloading sentence_transformers-5.2.2-py3-none-any.whl (494 kB)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-5.2.2

# %% [markdown]
# ## Sentiment Analysis Pipeline

# %%
from transformers import pipeline

classifier = pipeline(task="sentiment-analysis", model="distilbert/distilbert-base-uncased-finetuned-sst-2-english")

prompt = list(input("Enter double-hyphen-separated values for sentiment analysis:").split("--"))

results = classifier(prompt)
print(results)
# Out:
# Loading weights: 100%|██████████| 104/104 [00:00<00:00, 980.73it/s, Materializing param=pre_classifier.weight]
# [{'label': 'NEGATIVE', 'score': 0.9945736527442932}, {'label': 'POSITIVE', 'score': 0.999817430973053}]

# %% [markdown]
# ## Text-to-Image Generation

# %%
import torch
from diffusers import FluxPipeline

device = "cuda" if torch.cuda.is_available() else "cpu"
dtype = torch.float16 if device == "cuda" else torch.float32

pipe = FluxPipeline.from_pretrained(
    "black-forest-labs/FLUX.1-dev",
    torch_dtype=dtype
)

pipe = pipe.to(device)

# Memory optimizations (VERY important)
pipe.enable_attention_slicing()
pipe.vae.enable_slicing()

generator = torch.Generator(device).manual_seed(0)

prompt = input("Input something to generate an image")

image = pipe(
    prompt,
    height=1024,
    width=1024,
    guidance_scale=3.5,
    num_inference_steps=40,  # 50 is overkill for FLUX
    max_sequence_length=512,
    generator=generator
).images[0]

image.save("flux-dev.png")

# %% [markdown]
# ## Clustering & Semantic Search Embeddings

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import torch.nn.functional as F

#Mean Pooling - Take attention mask into account for correct averaging
def mean_pooling(model_output, attention_mask):
    token_embeddings = model_output[0] # First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-9)


# Sentences we want sentence embeddings for
sentences = ["To be, or not to be; that is the question.", 
             "Whether 'tis nobler in the mind to suffer the slings and arrows of outrageous fortune, or to take arms against a sea of troubles, and by opposing end them"]

# Load model
tokenizer = AutoTokenizer.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')
model = AutoModel.from_pretrained('sentence-transformers/all-MiniLM-L6-v2')

# Tokenization
encoded_input = tokenizer(sentences, padding=True, truncation=True, return_tensors='pt')

# Compute token embeddings
with torch.no_grad():
    model_output = model(**encoded_input)

# Perform pooling
sentence_embeddings = mean_pooling(model_output, encoded_input['attention_mask'])

# Normalize embeddings
sentence_embeddings = F.normalize(sentence_embeddings)

print(f"Sentence embeddings:\n{sentence_embeddings}")

# %% [markdown]
# ## Financial News Sentiment Analysis

# %%
import torch
import torch.nn.functional as F

from transformers import AutoTokenizer, AutoModelForSequenceClassification

checkpoint = "mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis"
tokenizer = AutoTokenizer.from_pretrained(checkpoint)
model = AutoModelForSequenceClassification.from_pretrained(checkpoint)
sequences = ["The Fed has declared a 0.2% increase in interest rates", "TSLA's stock price has sky-rocketed in the last 24 hours."]

tokens = tokenizer(sequences, padding=True, truncation=True, return_tensors="pt")
output = model(**tokens)


# with torch.no_grad():
#     output = model(**tokens)

logits = output.logits
probs = F.softmax(logits, dim=-1)

predicted_class_ids = torch.argmax(probs, dim=-1).tolist()
predicted_labels =  [model.config.id2label[i] for i in predicted_class_ids]

for s, l, p, c in zip(sequences, predicted_labels, probs, predicted_class_ids):
    print(f"The statement '{s}' is classified as having {l} sentiment at a {p[c]:.4f} probability")
# Out:
# Loading weights:   0%|          | 0/105 [00:00<?, ?it/s]
# RobertaForSequenceClassification LOAD REPORT from: mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis
# Key                             | Status     |  |
# --------------------------------+------------+--+-
# roberta.embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# The statement 'The Fed has declared a 0.2% increase in interest rates' is classified as having positive sentiment at a 0.9956 probability
# The statement 'TSLA's stock price has sky-rocketed in the last 24 hours.' is classified as having positive sentiment at a 0.9991 probability
